# %%
import os
import pandas as pd

# %%
BASE_DIR = os.path.dirname(os.getcwd())
DATA_DIR = os.path.join(BASE_DIR, 'data')
CACHE_DIR = os.path.join(BASE_DIR, 'cache')
os.makedirs(CACHE_DIR, exist_ok=True)
working_file = os.path.join(CACHE_DIR, 'movies-box-office-dataset.csv')
output_file = os.path.join(CACHE_DIR, 'movies-box-office-dataset-cleaned.csv')

# %%
df = pd.read_csv(working_file)

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0     1                Harry Potter and the Goblet of Fire  $895,921,036
# 1     2       Star Wars: Episode III - Revenge of the Sith  $868,352,530
# 2     3  The Chronicles of Narnia: The Lion, the Witch ...  $745,013,115
# 3     4                                  War of the Worlds  $603,873,119
# 4     5                                          King Kong  $562,363,449
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $290,013,036  32.4%  $605,908,000  67.6%  2005.csv  2005
# 1  $380,270,577  43.8%  $488,081,953  56.2%  2005.csv  2005
# 2  $291,710,957  39.2%  $453,302,158  60.8%  2005.csv  2005
# 3  $234,280,354  38.8%  $369,592,765  61.2%  2005.csv  2005
# 4  $218,080,025  38.8%  $344,283,424  61.2%  2005.csv  2005

# %%
df.head()
# rank does not make sense now, need to re-assign ranks
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0     1                Harry Potter and the Goblet of Fire  $895,921,036
# 1     2       Star Wars: Episode III - Revenge of the Sith  $868,352,530
# 2     3  The Chronicles of Narnia: The Lion, the Witch ...  $745,013,115
# 3     4                                  War of the Worlds  $603,873,119
# 4     5                                          King Kong  $562,363,449
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $290,013,036  32.4%  $605,908,000  67.6%  2005.csv  2005
# 1  $380,270,577  43.8%  $488,081,953  56.2%  2005.csv  2005
# 2  $291,710,957  39.2%  $453,302,158  60.8%  2005.csv  2005
# 3  $234,280,354  38.8%  $369,592,765  61.2%  2005.csv  2005
# 4  $218,080,025  38.8%  $344,283,424  61.2%  2005.csv  2005

# %%
df['Rank'] = -1

# %%
df.head()
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                Harry Potter and the Goblet of Fire  $895,921,036
# 1    -1       Star Wars: Episode III - Revenge of the Sith  $868,352,530
# 2    -1  The Chronicles of Narnia: The Lion, the Witch ...  $745,013,115
# 3    -1                                  War of the Worlds  $603,873,119
# 4    -1                                          King Kong  $562,363,449
#
#        Domestic      %       Foreign    %.1  filename  year
# 0  $290,013,036  32.4%  $605,908,000  67.6%  2005.csv  2005
# 1  $380,270,577  43.8%  $488,081,953  56.2%  2005.csv  2005
# 2  $291,710,957  39.2%  $453,302,158  60.8%  2005.csv  2005
# 3  $234,280,354  38.8%  $369,592,765  61.2%  2005.csv  2005
# 4  $218,080,025  38.8%  $344,283,424  61.2%  2005.csv  2005

# %%
# updating correct col names 
df['Domestic %'] = df['%']
df['Foreign %'] = df['%.1']
df.drop(['%', '%.1'], axis=1, inplace=True)

# %%
df['Worldwide'] = df['Worldwide'].replace("$", "").replace(",", "")
df.head() # nothing happens like this
# Out:
#    Rank                                      Release Group     Worldwide  \
# 0    -1                Harry Potter and the Goblet of Fire  $895,921,036
# 1    -1       Star Wars: Episode III - Revenge of the Sith  $868,352,530
# 2    -1  The Chronicles of Narnia: The Lion, the Witch ...  $745,013,115
# 3    -1                                  War of the Worlds  $603,873,119
# 4    -1                                          King Kong  $562,363,449
#
#        Domestic       Foreign  filename  year Domestic % Foreign %
# 0  $290,013,036  $605,908,000  2005.csv  2005      32.4%     67.6%
# 1  $380,270,577  $488,081,953  2005.csv  2005      43.8%     56.2%
# 2  $291,710,957  $453,302,158  2005.csv  2005      39.2%     60.8%
# 3  $234,280,354  $369,592,765  2005.csv  2005      38.8%     61.2%
# 4  $218,080,025  $344,283,424  2005.csv  2005      38.8%     61.2%

# %%
to_be_mod_cols = ['Worldwide', 'Domestic', 'Foreign']

def currency_to_int(current_val):
    currency_val = current_val.replace("$", "").replace(",", "")
    try:
        currency_val = int(currency_val)
    except:
        # Takes any row value with "-" and turns into 0
        currency_val = 0
    return currency_val 

def clean_cols(row):
    """
        row = Pandas Series
        dataframe = collection of Pandas Series
    """
    for col in to_be_mod_cols:
        current_val = row[col]
        row[col] = currency_to_int(current_val)
    return row
    
df_cleaned = df.apply(clean_cols, axis=1)
df_cleaned.head()
# Out:
#    Rank                                      Release Group  Worldwide  \
# 0    -1                Harry Potter and the Goblet of Fire  895921036
# 1    -1       Star Wars: Episode III - Revenge of the Sith  868352530
# 2    -1  The Chronicles of Narnia: The Lion, the Witch ...  745013115
# 3    -1                                  War of the Worlds  603873119
# 4    -1                                          King Kong  562363449
#
#     Domestic    Foreign  filename  year Domestic % Foreign %
# 0  290013036  605908000  2005.csv  2005      32.4%     67.6%
# 1  380270577  488081953  2005.csv  2005      43.8%     56.2%
# 2  291710957  453302158  2005.csv  2005      39.2%     60.8%
# 3  234280354  369592765  2005.csv  2005      38.8%     61.2%
# 4  218080025  344283424  2005.csv  2005      38.8%     61.2%

# %%
df.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide        object
# Domestic         object
# Foreign          object
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df_cleaned.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Foreign           int64
# filename         object
# year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df_cleaned.head()
# Out:
#    Rank                                      Release Group  Worldwide  \
# 0    -1                Harry Potter and the Goblet of Fire  895921036
# 1    -1       Star Wars: Episode III - Revenge of the Sith  868352530
# 2    -1  The Chronicles of Narnia: The Lion, the Witch ...  745013115
# 3    -1                                  War of the Worlds  603873119
# 4    -1                                          King Kong  562363449
#
#     Domestic    Foreign  filename  year Domestic % Foreign %
# 0  290013036  605908000  2005.csv  2005      32.4%     67.6%
# 1  380270577  488081953  2005.csv  2005      43.8%     56.2%
# 2  291710957  453302158  2005.csv  2005      39.2%     60.8%
# 3  234280354  369592765  2005.csv  2005      38.8%     61.2%
# 4  218080025  344283424  2005.csv  2005      38.8%     61.2%

# %%
df_cleaned['Domestic %'] = df_cleaned['Domestic'] / df_cleaned['Worldwide']
df_cleaned['Foreign %'] = df_cleaned['Foreign'] / df_cleaned['Worldwide']

# %%
df_cleaned.head()
# Out:
#    Rank                                      Release Group  Worldwide  \
# 0    -1                Harry Potter and the Goblet of Fire  895921036
# 1    -1       Star Wars: Episode III - Revenge of the Sith  868352530
# 2    -1  The Chronicles of Narnia: The Lion, the Witch ...  745013115
# 3    -1                                  War of the Worlds  603873119
# 4    -1                                          King Kong  562363449
#
#     Domestic    Foreign  filename  year  Domestic %  Foreign %
# 0  290013036  605908000  2005.csv  2005    0.323704   0.676296
# 1  380270577  488081953  2005.csv  2005    0.437922   0.562078
# 2  291710957  453302158  2005.csv  2005    0.391551   0.608449
# 3  234280354  369592765  2005.csv  2005    0.387963   0.612037
# 4  218080025  344283424  2005.csv  2005    0.387792   0.612208

# %%
# reassigning ranks : 
df_cleaned.sort_values(by=['Worldwide'], inplace=True, ascending=False)

# %%
df_cleaned.head()
# Out:
#       Rank                               Release Group   Worldwide   Domestic  \
# 9474    -1                           Avengers: Endgame  2797800564  858373000
# 2478    -1                                      Avatar  2744336793  749766139
# 6300    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 8574    -1                      Avengers: Infinity War  2048359754  678815482
# 6301    -1                              Jurassic World  1670400637  652270625
#
#          Foreign  filename  year  Domestic %  Foreign %
# 9474  1939427564  2019.csv  2019    0.306803   0.693197
# 2478  1994570654  2009.csv  2009    0.273205   0.726795
# 6300  1131561399  2015.csv  2015    0.452882   0.547118
# 8574  1369544272  2018.csv  2018    0.331395   0.668605
# 6301  1018130012  2015.csv  2015    0.390488   0.609512

# %%
df_cleaned.reset_index(inplace=True, drop=True)
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0    -1                           Avengers: Endgame  2797800564  858373000
# 1    -1                                      Avatar  2744336793  749766139
# 2    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 3    -1                      Avengers: Infinity War  2048359754  678815482
# 4    -1                              Jurassic World  1670400637  652270625
#
#       Foreign  filename  year  Domestic %  Foreign %
# 0  1939427564  2019.csv  2019    0.306803   0.693197
# 1  1994570654  2009.csv  2009    0.273205   0.726795
# 2  1131561399  2015.csv  2015    0.452882   0.547118
# 3  1369544272  2018.csv  2018    0.331395   0.668605
# 4  1018130012  2015.csv  2015    0.390488   0.609512

# %%
df_cleaned['Rank'] = df_cleaned.index + 1
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2                                      Avatar  2744336793  749766139
# 2     3  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 3     4                      Avengers: Infinity War  2048359754  678815482
# 4     5                              Jurassic World  1670400637  652270625
#
#       Foreign  filename  year  Domestic %  Foreign %
# 0  1939427564  2019.csv  2019    0.306803   0.693197
# 1  1994570654  2009.csv  2009    0.273205   0.726795
# 2  1131561399  2015.csv  2015    0.452882   0.547118
# 3  1369544272  2018.csv  2018    0.331395   0.668605
# 4  1018130012  2015.csv  2015    0.390488   0.609512

# %%
df.to_csv(output_file, index=False)
